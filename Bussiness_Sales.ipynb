# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("/content/Business_sales_EDA.csv" , sep=" ; ")

# %%
print(df.head())
# Out:
#   Product ID;Product Position;Promotion;Product Category;Seasonal;Sales Volume;brand;url;name;description;price;currency;terms;section;season;material;origin
# 0  185102;Aisle;Yes;clothing;Yes;1243;Zara;https:...
# 1  188771;Aisle;Yes;clothing;No;1429;Zara;https:/...
# 2  180176;End-cap;Yes;clothing;Yes;1168;Zara;http...
# 3  112917;Aisle;Yes;clothing;No;1348;Zara;https:/...
# 4  192936;End-cap;Yes;clothing;Yes;1602;Zara;http...

# %%
print(df.shape)
# Out:
# (20252, 1)

# %%
print(df.columns)
# Out:
# Index(['Product ID;Product Position;Promotion;Product Category;Seasonal;Sales Volume;brand;url;name;description;price;currency;terms;section;season;material;origin'], dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20252 entries, 0 to 20251
# Data columns (total 1 columns):
#  #   Column                                                                                                                                                       Non-Null Count  Dtype
# ---  ------                                                                                                                                                       --------------  -----
#  0   Product ID;Product Position;Promotion;Product Category;Seasonal;Sales Volume;brand;url;name;description;price;currency;terms;section;season;material;origin  20252 non-null  object
# dtypes: object(1)
# memory usage: 158.3+ KB
# None

# %%
print("Initial Shape: ", df.shape)
# Out:
# Initial Shape:  (20252, 1)

# %%
df.columns = df.columns.str.strip().str.lower().str.replace (" ", "_")

# %%
print(df.columns.tolist())
# Out:
# ['product_id;product_position;promotion;product_category;seasonal;sales_volume;brand;url;name;description;price;currency;terms;section;season;material;origin']

# %%
#Remove Duplicates Products
df = df.drop_duplicates(subset="product_id")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-866231533.py in <cell line: 0>()
#       1 #Remove Duplicates Products
# ----> 2 df = df.drop_duplicates(subset="Product ID")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop_duplicates(self, subset, keep, inplace, ignore_index)
#    6816         ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
#    6817
# -> 6818         result = self[-self.duplicated(subset, keep=keep)]
#    6819         if ignore_index:
#    6820             result.index = default_index(len(result))
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in duplicated(self, subset, keep)
#    6948         diff = set(subset) - set(self.columns)
#    6949         if diff:
# -> 6950             raise KeyError(Index(diff))
#    6951
#    6952         if len(subset) == 1 and self.columns.is_unique:
#
# KeyError: Index(['Product ID'], dtype='object')
